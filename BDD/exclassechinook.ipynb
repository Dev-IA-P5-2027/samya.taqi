# %%
import sqlite3
import os 
import sys

# %%
class Chinook:
    def __init__(self):

        self.conn= "ma connexion"
        self.cursor = "mon curseur"

    def test(self):
        print(self.connection)
        print(self.cursor)
    
    def __init__(self, chinook_db_path:str):
        """
        Initialise la connexion à la base SQLite et crée un curseur.
        """
        # self.connection = None
        # self.cursor = None
        # try:
        self.connection= sqlite3.connect(chinook_db_path)
        self.cursor = self.connection.cursor()
        #     print(f"Connexion réussie à {chinook_db}")
        # except Error as e:
        #     print(f"Erreur de connexion à la base : {e}")

db = Chinook(r"U:\BDD\data\chinook.db")
db.test()

# %%
def connection(self, chinook_db_path:str):
    self.conn=sqlite3.connection(r"U:\BDD\data\chinook.db")
    self.conn.commit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 4
#       2     self.conn=sqlite3.connection(r"U:\BDD\data\chinook.db")
#       3     return
# ----> 4 conn=sqlite3.connection(self,r"U:\BDD\data\chinook.db")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\sqlite3\__init__.py:70, in __getattr__(name)
#      67     warn(f"{name} is deprecated and will be removed in Python 3.14",
#      68          DeprecationWarning, stacklevel=2)
#      69     return globals()[f"_deprecated_{name}"]
# ---> 70 raise AttributeError(f"module {__name__!r} has no attribute {name!r}")
#
# AttributeError: module 'sqlite3' has no attribute 'connection'

# %%
cursor.execute("PRAGMA table_info(albums)").fetchall()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 cursor.execute("PRAGMA table_info(albums)").fetchall()
#
# NameError: name 'cursor' is not defined

# %%
def get_artist_by_id(cursor, artist_id):
