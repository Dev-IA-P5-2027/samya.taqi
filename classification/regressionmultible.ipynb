# %%
import numpy as np
def predict_multiple(X,W,b):
    return X @ W +b

def mse_loss(y_hat, y):
    return np.mean((y_hat - y)**2)

def fit_linear_multiple_gd(X,y,lr=0.05, epochs=2000, seed=0):
    X=np.asarray(X)
    y=np.asarray(y).reshape(-1,1)
    n,d=X.shape
    rng=np.random.defaults_rng(seed)
    W=rng.normal(0,0.01, size=(d,1))
    b=0.0
    for _ in range(epochs):
