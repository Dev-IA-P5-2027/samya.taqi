# %%
import numpy as np

# %%
A=np.array([
    [1,2,3],
    [4,5,6]
])
print(A) # dimension de 2X3
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
A.shape # pour regarder la dimension (lignes, colonnes)
# Out:
# (2, 3)

# %% [markdown]
# **Accéder aux éléments**

# %%
A[0,1] #0 lignes /  1 colonnes
# Out:
# np.int64(2)

# %%
#ligne compléte 
A[0]
# Out:
# array([1, 2, 3])

# %%
A[:,1]  #colonnes complète
# Out:
# array([2, 5])

# %% [markdown]
# **opérations**

# %%
B=np.array([
    [7,8,9],
    [1,2,3]
])
print(A+B)
# Out:
# [[ 8 10 12]
#  [ 5  7  9]]

# %%
#multiplication par scalaire 
A*2
# Out:
# array([[ 2,  4,  6],
#        [ 8, 10, 12]])

# %%
C=B.T
C
# Out:
# array([[7, 1],
#        [8, 2],
#        [9, 3]])

# %%
#produit matriciel 
np.dot(C,B)
# Out:
# array([[50, 58, 66],
#        [58, 68, 78],
#        [66, 78, 90]])
